# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# # Importer un csv

# %%
election_df = pd.read_csv('/work/president_county.csv', sep=",")

# %%
election_df
# Out:
#                      state                county  current_votes  total_votes  \
# 0                 Delaware           Kent County          87025        87025
# 1                 Delaware     New Castle County         287633       287633
# 2                 Delaware         Sussex County         129352       129352
# 3     District of Columbia  District of Columbia          41681        41681
# 4     District of Columbia                Ward 2          32881        32881
# ...                    ...                   ...            ...          ...
# 4628               Arizona         Graham County          14996        14996
# 4629               Arizona       Greenlee County           3688         3688
# 4630               Arizona         La Paz County           7460         7460
# 4631               Arizona       Maricopa County        2069475      2068144
# 4632               Arizona         Mohave County         104705       104705
#
#       percent
# 0         100
# ...

# %% [markdown]
# Jeter un coup d'oeil sur les données

# %%
# Afficher quelques unes des premières infos. -> tail pour la fin
election_df.head(20)
# Out:
#                    state                county  current_votes  total_votes  \
# 0               Delaware           Kent County          87025        87025
# 1               Delaware     New Castle County         287633       287633
# 2               Delaware         Sussex County         129352       129352
# 3   District of Columbia  District of Columbia          41681        41681
# 4   District of Columbia                Ward 2          32881        32881
# 5   District of Columbia                Ward 3          44231        44231
# 6   District of Columbia                Ward 4          45296        45296
# 7   District of Columbia                Ward 5          46107        46107
# 8   District of Columbia                Ward 6          62918        62918
# 9   District of Columbia                Ward 7          38384        38384
# 10  District of Columbia                Ward 8          32858        32858
# ...

# %%
# Afficher les "features" (colonnes) 
election_df.columns
# Out:
# Index(['state', 'county', 'current_votes', 'total_votes', 'percent'], dtype='object')

# %%
# First impression counts!
election_df.describe().T
# Out:
#                 count          mean            std   min     25%     50%  \
# current_votes  4633.0  34450.299374  124401.392456   0.0  2327.0  7765.0
# total_votes    4633.0  34484.612562  124911.164198   0.0  2326.0  7695.0
# percent        4633.0     99.579754       1.807009  69.0   100.0   100.0
#
#                    75%        max
# current_votes  20346.0  4263443.0
# total_votes    20346.0  4263443.0
# percent          100.0      100.0

# %%
election_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4633 entries, 0 to 4632
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   state          4633 non-null   object
#  1   county         4633 non-null   object
#  2   current_votes  4633 non-null   int64
#  3   total_votes    4633 non-null   int64
#  4   percent        4633 non-null   int64
# dtypes: int64(3), object(2)
# memory usage: 181.1+ KB

# %%
# Sélectionner les valeurs d'une colonne (une série)
election_df['state']
election_df['county'].unique()
# Out:
# numpy.ndarray

# %%
# Sélectionner plusieurs colonnes (en créer un sous-ensemble ?)
state_county = election_df[['state','county']]
state_county
# Out:
#                      state                county
# 0                 Delaware           Kent County
# 1                 Delaware     New Castle County
# 2                 Delaware         Sussex County
# 3     District of Columbia  District of Columbia
# 4     District of Columbia                Ward 2
# ...                    ...                   ...
# 4628               Arizona         Graham County
# 4629               Arizona       Greenlee County
# 4630               Arizona         La Paz County
# 4631               Arizona       Maricopa County
# 4632               Arizona         Mohave County
#
# [4633 rows x 2 columns]

# %%
# Cibler une ligne
election_df.iloc[0]
# Out:
# state               Delaware
# county           Kent County
# current_votes          87025
# total_votes            87025
# percent                  100
# Name: 0, dtype: object

# %%
# Plusieurs lignes
election_df.iloc[0:5]
# Out:
#                   state                county  current_votes  total_votes  \
# 0              Delaware           Kent County          87025        87025
# 1              Delaware     New Castle County         287633       287633
# 2              Delaware         Sussex County         129352       129352
# 3  District of Columbia  District of Columbia          41681        41681
# 4  District of Columbia                Ward 2          32881        32881
#
#    percent
# 0      100
# 1      100
# 2      100
# 3      100
# 4      100

# %% [markdown]
# Selectionner lignes et colonnes

# %%
# cibler lignes*colonnes avec iloc
election_df.iloc[0:5][['state','county', 'total_votes']]
# Out:
#                   state                county  total_votes
# 0              Delaware           Kent County        87025
# 1              Delaware     New Castle County       287633
# 2              Delaware         Sussex County       129352
# 3  District of Columbia  District of Columbia        41681
# 4  District of Columbia                Ward 2        32881

# %%
# Supprimer une colonne
# election_df = election_df.de
election_df.drop(election_df.index[0:4],0, inplace=True)
election_df
# Out:
#                      state           county  current_votes  total_votes  \
# 4     District of Columbia           Ward 2          32881        32881
# 5     District of Columbia           Ward 3          44231        44231
# 6     District of Columbia           Ward 4          45296        45296
# 7     District of Columbia           Ward 5          46107        46107
# 8     District of Columbia           Ward 6          62918        62918
# ...                    ...              ...            ...          ...
# 4628               Arizona    Graham County          14996        14996
# 4629               Arizona  Greenlee County           3688         3688
# 4630               Arizona    La Paz County           7460         7460
# 4631               Arizona  Maricopa County        2069475      2068144
# 4632               Arizona    Mohave County         104705       104705
#
#       percent
# 4         100
# 5         100
# 6         100
# 7         100
# 8         100
# ...

# %% [markdown]
# Conter le nombre de modalitées

# %%
# Compter le nombre de modalités
pd.value_counts(election_df['state'])
# Out:
# Maine                   498
# Massachusetts           351
# Texas                   254
# Vermont                 246
# New Hampshire           237
# Connecticut             169
# Georgia                 159
# Virginia                133
# Kentucky                120
# Missouri                115
# Kansas                  105
# Illinois                103
# North Carolina          100
# Iowa                     99
# Tennessee                95
# Nebraska                 93
# Indiana                  92
# Ohio                     88
# Minnesota                87
# Michigan                 83
# Mississippi              82
# Oklahoma                 77
# Arkansas                 75
# Wisconsin                72
# Alabama                  67
# Pennsylvania             67
# Florida                  67
# South Dakota             66
# Colorado                 64
# Louisiana                64
# New York                 62
# California               58
# Montana                  56
# ...

# %% [markdown]
# Faire un group by

# %%
#Group by
election_df.groupby(['state']).mean()['total_votes']
# Out:
# state
# Alabama                  34675.910448
# Alaska                    9783.650000
# Arizona                 225724.200000
# Arkansas                 16254.253333
# California              301653.551724
# Colorado                 50890.046875
# Connecticut              10814.840237
# District of Columbia     43239.285714
# Florida                 165185.910448
# Georgia                  31418.188679
# Hawaii                  143617.250000
# Idaho                    19730.750000
# Illinois                 70470.194175
# Indiana                  32984.934783
# Iowa                     17090.404040
# Kansas                   12802.038095
# Kentucky                 17815.775000
# Louisiana                33563.468750
# Maine                     1636.925703
# Maryland                126542.916667
# Massachusetts            10345.188034
# Michigan                 66738.578313
# Minnesota                38674.885057
# Mississippi              16194.060976
# ...

# %%
# Filtrer
election_df[election_df['percent']<90].reset_index()
# Out:
#     index          state               county  current_votes  total_votes  \
# 0     286       Illinois     Alexander County           2618         3010
# 1     319       Illinois        Hardin County           2162         2514
# 2     323       Illinois       Jackson County          22716        27180
# 3     361       Illinois       Pulaski County           2631         3260
# 4     367       Illinois        Saline County          11089        12471
# 5     579         Kansas         Allen County           5842         7429
# 6     590         Kansas      Cheyenne County           1400         1621
# 7     598         Kansas       Decatur County           1458         1742
# 8     611         Kansas        Graham County           1302         1523
# 9     614         Kansas       Greeley County            629          761
# 10    616         Kansas      Hamilton County            837          951
# 11    620         Kansas      Hodgeman County           1033         1205
# ...

# %% [markdown]
# Trier

# %%
election_df.sort_values('percent')
# Out:
#               state               county  current_votes  total_votes  percent
# 653          Kansas  Pottawatomie County          12815        18500       69
# 1022          Maine           Frenchboro             31           43       72
# 3317          Texas        Brooks County           2484         3375       74
# 579          Kansas         Allen County           5842         7429       79
# 361        Illinois       Pulaski County           2631         3260       81
# ...             ...                  ...            ...          ...      ...
# 1672  Massachusetts             Rockland           9994         9994      100
# 1673  Massachusetts             Scituate          13530        13530      100
# 1674  Massachusetts              Wareham          12726        12726      100
# 1660  Massachusetts                 Hull           7080         7080      100
# 4632        Arizona        Mohave County         104705       104705      100
#
# [4629 rows x 5 columns]

# %%
df.sort_values('percent', ascending = False)
# Out:
#               state               county  current_votes  total_votes  percent
# 0          Delaware          Kent County          87025        87025      100
# 2304  New Hampshire         Chesterfield           2392         2392      100
# 3083   Rhode Island             Coventry          20004        19915      100
# 3082   Rhode Island          Charlestown           5220         5193      100
# 3081   Rhode Island        Central Falls           4272         4256      100
# ...             ...                  ...            ...          ...      ...
# 361        Illinois       Pulaski County           2631         3260       81
# 579          Kansas         Allen County           5842         7429       79
# 3317          Texas        Brooks County           2484         3375       74
# 1022          Maine           Frenchboro             31           43       72
# 653          Kansas  Pottawatomie County          12815        18500       69
#
# [4633 rows x 5 columns]

# %%
election_df.head()
# Out:
#                   state  county  current_votes  total_votes  percent
# 4  District of Columbia  Ward 2          32881        32881      100
# 5  District of Columbia  Ward 3          44231        44231      100
# 6  District of Columbia  Ward 4          45296        45296      100
# 7  District of Columbia  Ward 5          46107        46107      100
# 8  District of Columbia  Ward 6          62918        62918      100

# %%
# Modifier des valeurs 
election_df.loc[election_df['state'] == 'District of Columbia','state'] = 'Columbia'
election_df
# Out:
#          state           county  current_votes  total_votes  percent
# 4     Columbia           Ward 2          32881        32881      100
# 5     Columbia           Ward 3          44231        44231      100
# 6     Columbia           Ward 4          45296        45296      100
# 7     Columbia           Ward 5          46107        46107      100
# 8     Columbia           Ward 6          62918        62918      100
# ...        ...              ...            ...          ...      ...
# 4628   Arizona    Graham County          14996        14996      100
# 4629   Arizona  Greenlee County           3688         3688      100
# 4630   Arizona    La Paz County           7460         7460      100
# 4631   Arizona  Maricopa County        2069475      2068144      100
# 4632   Arizona    Mohave County         104705       104705      100
#
# [4629 rows x 5 columns]

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=fe5582f2-aaf4-4c4b-afc2-44df05c82ae3' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
