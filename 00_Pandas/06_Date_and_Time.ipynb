# %% [markdown]
# # Imports

# %%
from datetime import datetime
from datetime import timedelta
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Your mission: convert each string variable into datetime objects

# %%
var1 = '2018-01-04'
print(type(var1))
print(var1)
# Out:
# <class 'str'>
# 2018-01-04

# %%
# It's up to you :

var1 = datetime.strptime('2018-01-04', '%Y-%m-%d')
print(type(var1))
print(var1)
# Out:
# <class 'datetime.datetime'>
# 2018-01-04 00:00:00

# %%
var2 = '14/02/2019'
# It's up to you :

var2 = datetime.strptime('14/02/2019', '%d/%m/%Y')
print(type(var2))
print(var2)
# Out:
# <class 'datetime.datetime'>
# 2019-02-14 00:00:00

# %%
var3 = '14 03 20'
# It's up to you :

var3 = datetime.strptime('14 03 20', '%d %m %y')
print(type(var3))
print(var3)
# Out:
# <class 'datetime.datetime'>
# 2020-03-14 00:00:00

# %%
var4 = '14/02/2019 21:30'
# It's up to you :

var4 = datetime.strptime('14/02/2019 21:30', '%d/%m/%Y %H:%M')
print(type(var4))
print(var4)
# Out:
# <class 'datetime.datetime'>
# 2019-02-14 21:30:00

# %%
var5 = '2018-01-04 at 18 hours and 48 min'
# It's up to you :

var5 = datetime.strptime('2018-01-04 at 18 hours and 48 min', '%Y-%m-%d at %H hours and %M min')
print(type(var5))
print(var5)
# Out:
# <class 'datetime.datetime'>
# 2018-01-04 18:48:00

# %% [markdown]
# # Your mission: convert the datetime object into string with precise format

# %%
var_date = datetime.strptime('2020-02-15 20:05', '%Y-%m-%d %H:%M')
var_date = datetime.strftime(var_date, '%Y-%m-%d %H:%M')
print(type(var_date))
print(var_date)
# Out:
# <class 'str'>
# 2020-02-15 20:05

# %%
# We would like to print this format : 15/02/2020

var_date1 = datetime.strptime('15/02/2020', '%d/%m/%Y')
var_date1 = datetime.strftime(var_date1, '%d/%m/%Y')
print(type(var_date1))
print(var_date1)
# Out:
# <class 'str'>
# 15/02/2020

# %%
# We would like to print this format : 15-02-2020

var_date2 = datetime.strptime('15-02-2020', '%d-%m-%Y')
var_date2 = datetime.strftime(var_date2, '%d-%m-%Y')
print(type(var_date2))
print(var_date2)
# Out:
# <class 'str'>
# 15-02-2020

# %%
# We would like to print this format : 15/02

var_date3 = datetime.strptime('15/02', '%d/%m')
var_date3 = datetime.strftime(var_date3, '%d/%m')
print(type(var_date3))
print(var_date3)
# Out:
# <class 'str'>
# 15/02

# %%
# We would like to print this format : 2020-02

var_date4 = datetime.strptime('2020-02', '%Y-%m')
var_date4 = datetime.strftime(var_date4, '%Y-%m')
print(type(var_date4))
print(var_date4)
# Out:
# <class 'str'>
# 2020-02

# %%
# We would like to print this format : 2020-02-15 at 20:05

var_date5 = datetime.strptime('2020-02-15 at 20:05', '%Y-%m-%d at %H:%M')
var_date5 = datetime.strftime(var_date5, '%Y-%m-%d at %H:%M')
print(type(var_date5))
print(var_date5)
# Out:
# <class 'str'>
# 2020-02-15 at 20:05

# %% [markdown]
# # Your mission is to determine which date it was / it will be

# %%
# what month will it be in 7 weeks ?
var0 = datetime.now() + timedelta(weeks=7)
month_name = var0.strftime("%B")
print(datetime.now() + timedelta(weeks=7))
print(month_name)
# Out:
# 2022-12-05 10:06:45.607167
# December

# %%
# what day of the week will it be in 3 days ?

var11 = datetime.now() + timedelta(days=3)
day_name = var0.strftime("%A")
print(datetime.now() + timedelta(days=3))
print(day_name)
# Out:
# 2022-10-20 10:08:37.550521
# Monday

# %%
# what hour will it be in 100 hours ?

print(datetime.now() + timedelta(hours=100))
# Out:
# 2022-10-21 12:46:12.981791

# %%
# what date was 30 days ago ?

print(datetime.now() - timedelta(days=30))
# Out:
# 2022-09-17 08:46:36.725802

# %%
# what date was 30 weeks ago ?

print(datetime.now() - timedelta(weeks=30))
# Out:
# 2022-03-21 08:46:51.786159

# %% [markdown]
# # With Pandas
# "DATE" column has only string values. On a chart, the X-axis is not well displayed.

# %%
# Please run this cell without modification:
df = pd.read_csv("https://raw.githubusercontent.com/murpi/wilddata/master/quests/weather2019.csv")
fig, ax = plt.subplots(figsize=(20, 10))
ax.scatter(x=df['DATE'], 
           y=df['MAX_TEMPERATURE_C'])
fig.show()

# %%
# Convert the "DATE" column into a datetime format, then display the same chart. Are ticks on X-axis better printed ?


df['DATE'] = df['DATE'].apply(lambda x: datetime.strptime(x, '%Y-%m-%d'))

fig1, ax = plt.subplots(figsize=(20, 10))
ax.scatter(x=df['DATE'], 
           y=df['MAX_TEMPERATURE_C'])

fig1.show()

# %%
# Display only rows for the month of June


df = df[pd.to_datetime(df['DATE']).dt.month == 6]

fig2, ax = plt.subplots(figsize=(20, 10))
ax.scatter(x=df['DATE'], 
           y=df['MAX_TEMPERATURE_C'])

fig2.show()
