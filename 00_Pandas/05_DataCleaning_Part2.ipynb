# %%
import pandas as pd # toujours pd !
import matplotlib.pyplot as plt

# %% [markdown]
# # 1. Importer les données

# %%
# juste pour me connecter à mon drive où est le jeu de données
from google.colab import drive
drive.mount('/drive')
# Out:
# Mounted at /drive

# %%
### 1e test
employ = pd.read_csv('/drive/My Drive/W6_pd_plt/W6_LC_DF_employees_avecmodifs.csv')

# %%
employ
# Out:
#                                                                                    Jeu de données avant modification issu de : https://media.geeksforgeeks.org/wp-content/uploads/employees.csv
# First Name last name Gender Salary  Bonus % Senior Management Team                                                         anciennete
# Douglas    Walsh     Male   97308E  6,945   T                 Marketing                                                          28.0
# Maria      Rhine     Female 130590E 11,858  F                 Finance                                                            28.0
# Jerry      Stelk     Male   138705E 9,34    T                 Finance                                                            16.0
# Larry      Sperdute  Male   101004E 1,389   T                 Client Services                                                    23.0
# ...

# %%
type(employ)
# Out:
# pandas.core.frame.DataFrame

# %%
### 2e test : YOUPI
employ = pd.read_csv('/drive/My Drive/W6_pd_plt/W6_LC_DF_employees_avecmodifs.csv', header=1)
# si j'avais eu besoin de changer l'encodage : encoding="latin1"
# ici je n'ai pas besoin !
employ
# Out:
#     First Name last name  Gender   Salary Bonus % Senior Management  \
# 0      Douglas     Walsh    Male   97308E   6,945                 T
# 1        Maria     Rhine  Female  130590E  11,858                 F
# 2        Jerry     Stelk    Male  138705E    9,34                 T
# 3        Larry  Sperdute    Male  101004E   1,389                 T
# 4       Dennis    Wilson    Male  115163E  10,125                 F
# ..         ...       ...     ...      ...     ...               ...
# 759     George    Cooney    Male   98874E   4,479                 T
# 760    Phillip   Randall    Male   42392E  19,675                 F
# 761    Russell  Martinez    Male   96914E   1,421                 F
# 762      Larry      Able    Male   60500E  11,985                 F
# 763     Albert    Earles    Male  129949E  10,169                 T
#
#                      Team  anciennete
# 0               Marketing        28.0
# 1                 Finance        28.0
# ...

# %% [markdown]
# # 2. Vérifications DF

# %%
employ.info()
# 764 lignes
# 8 colonnes
# 764 non-null : aucune valeur manquante pour toutes les colonnes, donc aucune valeur manquante dans ce df, youpi
# les types : ça a pas l'air foufou, on va faire des modifs
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 764 entries, 0 to 763
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         764 non-null    object
#  1   last name          764 non-null    object
#  2   Gender             764 non-null    object
#  3   Salary             764 non-null    object
#  4   Bonus %            764 non-null    object
#  5   Senior Management  764 non-null    object
#  6   Team               764 non-null    object
#  7   anciennete         764 non-null    float64
# dtypes: float64(1), object(7)
# memory usage: 47.9+ KB

# %%
employ
# Out:
#     First Name last name  Gender   Salary Bonus % Senior Management  \
# 0      Douglas     Walsh    Male   97308E   6,945                 T
# 1        Maria     Rhine  Female  130590E  11,858                 F
# 2        Jerry     Stelk    Male  138705E    9,34                 T
# 3        Larry  Sperdute    Male  101004E   1,389                 T
# 4       Dennis    Wilson    Male  115163E  10,125                 F
# ..         ...       ...     ...      ...     ...               ...
# 759     George    Cooney    Male   98874E   4,479                 T
# 760    Phillip   Randall    Male   42392E  19,675                 F
# 761    Russell  Martinez    Male   96914E   1,421                 F
# 762      Larry      Able    Male   60500E  11,985                 F
# 763     Albert    Earles    Male  129949E  10,169                 T
#
#                      Team  anciennete
# 0               Marketing        28.0
# 1                 Finance        28.0
# ...

# %%
# le T mes yeux de data analyst le voit comme un True
# mais pandas le voit comme la lettre T

# %% [markdown]
# ## 2.1 Modifier les types

# %% [markdown]
# * **Ancienneté**

# %%
employ["anciennete"].astype(int) # attention pas remplacé !
# Out:
# 0      28
# 1      28
# 2      16
# 3      23
# 4      34
#        ..
# 759     8
# 760    37
# 761     8
# 762     8
# 763     9
# Name: anciennete, Length: 764, dtype: int64

# %%
# pour vérifier
# employ

# %%
# maintenant que je suis sûre de moi :
employ["anciennete"] = employ["anciennete"].astype(int)
employ
# Out:
#     First Name last name  Gender   Salary Bonus % Senior Management  \
# 0      Douglas     Walsh    Male   97308E   6,945                 T
# 1        Maria     Rhine  Female  130590E  11,858                 F
# 2        Jerry     Stelk    Male  138705E    9,34                 T
# 3        Larry  Sperdute    Male  101004E   1,389                 T
# 4       Dennis    Wilson    Male  115163E  10,125                 F
# ..         ...       ...     ...      ...     ...               ...
# 759     George    Cooney    Male   98874E   4,479                 T
# 760    Phillip   Randall    Male   42392E  19,675                 F
# 761    Russell  Martinez    Male   96914E   1,421                 F
# 762      Larry      Able    Male   60500E  11,985                 F
# 763     Albert    Earles    Male  129949E  10,169                 T
#
#                      Team  anciennete
# 0               Marketing          28
# 1                 Finance          28
# ...

# %% [markdown]
# * **Senior Management**

# %%
employ["Senior Management"] # c'est une serie
# Out:
# 0      T
# 1      F
# 2      T
# 3      T
# 4      F
#       ..
# 759    T
# 760    F
# 761    F
# 762    F
# 763    T
# Name: Senior Management, Length: 764, dtype: object

# %%
### ATTENTION il n'y a pas de message d'erreur
employ["Senior Management"].astype(bool)
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 759    True
# 760    True
# 761    True
# 762    True
# 763    True
# Name: Senior Management, Length: 764, dtype: bool

# %%
# c'est mieux :
employ["Senior Management"].replace({"T": True, "F": False})
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 4      False
#        ...
# 759     True
# 760    False
# 761    False
# 762    False
# 763     True
# Name: Senior Management, Length: 764, dtype: bool

# %%
# version 1
# employ["Senior Management"] = employ["Senior Management"].replace({"T": True, "F": False})

# %%
# version 2
employ["Senior Management"].replace({"T": True, "F": False},
                                    inplace=True) # attention, que quand je suis sure !
employ
# Out:
#     First Name last name  Gender   Salary Bonus %  Senior Management  \
# 0      Douglas     Walsh    Male   97308E   6,945               True
# 1        Maria     Rhine  Female  130590E  11,858              False
# 2        Jerry     Stelk    Male  138705E    9,34               True
# 3        Larry  Sperdute    Male  101004E   1,389               True
# 4       Dennis    Wilson    Male  115163E  10,125              False
# ..         ...       ...     ...      ...     ...                ...
# 759     George    Cooney    Male   98874E   4,479               True
# 760    Phillip   Randall    Male   42392E  19,675              False
# 761    Russell  Martinez    Male   96914E   1,421              False
# 762      Larry      Able    Male   60500E  11,985              False
# 763     Albert    Earles    Male  129949E  10,169               True
#
#                      Team  anciennete
# 0               Marketing          28
# 1                 Finance          28
# ...

# %% [markdown]
# * **Salary**

# %% [markdown]
# * VERSION 1

# %%
### sur un exemple
exemple_salaire = "1249E"

# %%
exemple_salaire[:-1]
# Out:
# '1249'

# %%
### sur la colonne entière
employ["Salary"].str[:-1]
# Out:
# 0       97308
# 1      130590
# 2      138705
# 3      101004
# 4      115163
#         ...
# 759     98874
# 760     42392
# 761     96914
# 762     60500
# 763    129949
# Name: Salary, Length: 764, dtype: object

# %%
# attention ici c'est pas bon, il a juste enlever le 764ème élément :
employ["Salary"][:-1]
# Out:
# 0       97308E
# 1      130590E
# 2      138705E
# 3      101004E
# 4      115163E
#         ...
# 758     56450E
# 759     98874E
# 760     42392E
# 761     96914E
# 762     60500E
# Name: Salary, Length: 763, dtype: object

# %% [markdown]
# * VERSION 2

# %%
### sur un exemple
exemple_salaire = "1249E"
exemple_salaire.replace("E", "")
# Out:
# '1249'

# %%
### sur colonne entière
employ["Salary"].str.replace("E", "")
# Out:
# 0       97308
# 1      130590
# 2      138705
# 3      101004
# 4      115163
#         ...
# 759     98874
# 760     42392
# 761     96914
# 762     60500
# 763    129949
# Name: Salary, Length: 764, dtype: object

# %% [markdown]
# * MODIFICATION COMPLETE

# %%
employ["Salary"] = employ["Salary"].str.replace("E", "").astype(int)
employ
# Out:
#     First Name last name  Gender  Salary Bonus %  Senior Management  \
# 0      Douglas     Walsh    Male   97308   6,945               True
# 1        Maria     Rhine  Female  130590  11,858              False
# 2        Jerry     Stelk    Male  138705    9,34               True
# 3        Larry  Sperdute    Male  101004   1,389               True
# 4       Dennis    Wilson    Male  115163  10,125              False
# ..         ...       ...     ...     ...     ...                ...
# 759     George    Cooney    Male   98874   4,479               True
# 760    Phillip   Randall    Male   42392  19,675              False
# 761    Russell  Martinez    Male   96914   1,421              False
# 762      Larry      Able    Male   60500  11,985              False
# 763     Albert    Earles    Male  129949  10,169               True
#
#                      Team  anciennete
# 0               Marketing          28
# 1                 Finance          28
# ...

# %% [markdown]
# * **Bonus**

# %%
employ["Bonus %"] = employ["Bonus %"].str.replace(",", ".").astype(float)
employ
# Out:
#     First Name last name  Gender  Salary  Bonus %  Senior Management  \
# 0      Douglas     Walsh    Male   97308    6.945               True
# 1        Maria     Rhine  Female  130590   11.858              False
# 2        Jerry     Stelk    Male  138705    9.340               True
# 3        Larry  Sperdute    Male  101004    1.389               True
# 4       Dennis    Wilson    Male  115163   10.125              False
# ..         ...       ...     ...     ...      ...                ...
# 759     George    Cooney    Male   98874    4.479               True
# 760    Phillip   Randall    Male   42392   19.675              False
# 761    Russell  Martinez    Male   96914    1.421              False
# 762      Larry      Able    Male   60500   11.985              False
# 763     Albert    Earles    Male  129949   10.169               True
#
#                      Team  anciennete
# 0               Marketing          28
# 1                 Finance          28
# ...

# %% [markdown]
# ## 2.2 Renommer (bonus)

# %% [markdown]
# * **colonnes**

# %%
employ.columns
# Out:
# Index(['First Name', 'last name', 'Gender', 'Salary', 'Bonus %',
#        'Senior Management', 'Team', 'anciennete'],
#       dtype='object')

# %%
employ.columns = ["firstname", "lastname", "genre", "salaire", "bonus_pourc", "sen_man", "equipe", "anciennete"]
employ.columns
# attention, ne sert pas à ordonner les colonnes
# attention, recopier les noms de colonnes qui ne sont pas modifiés
# Out:
# Index(['firstname', 'lastname', 'genre', 'salaire', 'bonus_pourc', 'sen_man',
#        'equipe', 'anciennete'],
#       dtype='object')

# %%
employ
# Out:
#     firstname  lastname   genre  salaire  bonus_pourc  sen_man  \
# 0     Douglas     Walsh    Male    97308        6.945     True
# 1       Maria     Rhine  Female   130590       11.858    False
# 2       Jerry     Stelk    Male   138705        9.340     True
# 3       Larry  Sperdute    Male   101004        1.389     True
# 4      Dennis    Wilson    Male   115163       10.125    False
# ..        ...       ...     ...      ...          ...      ...
# 759    George    Cooney    Male    98874        4.479     True
# 760   Phillip   Randall    Male    42392       19.675    False
# 761   Russell  Martinez    Male    96914        1.421    False
# 762     Larry      Able    Male    60500       11.985    False
# 763    Albert    Earles    Male   129949       10.169     True
#
#                    equipe  anciennete
# 0               Marketing          28
# 1                 Finance          28
# 2                 Finance          16
# 3         Client Services          23
# ...

# %% [markdown]
# * **index**

# %%
# cette partie n'a pas été expliquée et me servira plus tard pédagogiquement,
# à vous de chercher à comprendre si vous le voulez ;)
employ.set_index(
    pd.Index(["emp" + str(i) for i in employ.index]),
    inplace=True)
employ
# Out:
#        firstname  lastname   genre  salaire  bonus_pourc  sen_man  \
# emp0     Douglas     Walsh    Male    97308        6.945     True
# emp1       Maria     Rhine  Female   130590       11.858    False
# emp2       Jerry     Stelk    Male   138705        9.340     True
# emp3       Larry  Sperdute    Male   101004        1.389     True
# emp4      Dennis    Wilson    Male   115163       10.125    False
# ...          ...       ...     ...      ...          ...      ...
# emp759    George    Cooney    Male    98874        4.479     True
# emp760   Phillip   Randall    Male    42392       19.675    False
# emp761   Russell  Martinez    Male    96914        1.421    False
# emp762     Larry      Able    Male    60500       11.985    False
# emp763    Albert    Earles    Male   129949       10.169     True
#
#                       equipe  anciennete
# emp0               Marketing          28
# emp1                 Finance          28
# emp2                 Finance          16
# ...

# %% [markdown]
# ## 2.3 Doublons

# %%
employ.info() # pour rappel
# ici je ne vois pas si il y a des doublons ou non
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 764 entries, emp0 to emp763
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   firstname    764 non-null    object
#  1   lastname     764 non-null    object
#  2   genre        764 non-null    object
#  3   salaire      764 non-null    int64
#  4   bonus_pourc  764 non-null    float64
#  5   sen_man      764 non-null    bool
#  6   equipe       764 non-null    object
#  7   anciennete   764 non-null    int64
# dtypes: bool(1), float64(1), int64(2), object(4)
# memory usage: 48.5+ KB

# %%
employ.duplicated()
# Out:
# emp0      False
# emp1      False
# emp2      False
# emp3      False
# emp4      False
#           ...
# emp759    False
# emp760    False
# emp761    False
# emp762    False
# emp763    False
# Length: 764, dtype: bool

# %%
# True : 1
# False : 0
employ.duplicated().sum()
# 0 : pas de doublons
# Out:
# 0

# %% [markdown]
# ## 2.5 autre
#
# --> dans ce LC je ne regarde pas les outliers\
# --> pas de valeurs manquantes : voir .info()

# %% [markdown]
# # 3. Premières statistiques

# %%
employ
# Out:
#        firstname  lastname   genre  salaire  bonus_pourc  sen_man  \
# emp0     Douglas     Walsh    Male    97308        6.945     True
# emp1       Maria     Rhine  Female   130590       11.858    False
# emp2       Jerry     Stelk    Male   138705        9.340     True
# emp3       Larry  Sperdute    Male   101004        1.389     True
# emp4      Dennis    Wilson    Male   115163       10.125    False
# ...          ...       ...     ...      ...          ...      ...
# emp759    George    Cooney    Male    98874        4.479     True
# emp760   Phillip   Randall    Male    42392       19.675    False
# emp761   Russell  Martinez    Male    96914        1.421    False
# emp762     Larry      Able    Male    60500       11.985    False
# emp763    Albert    Earles    Male   129949       10.169     True
#
#                       equipe  anciennete
# emp0               Marketing          28
# emp1                 Finance          28
# emp2                 Finance          16
# ...

# %%
### pour avoir une vue d'ensemble
employ.describe()
# Out:
#              salaire  bonus_pourc  anciennete
# count     764.000000   764.000000  764.000000
# mean    90433.196335    10.148041   22.316754
# std     32864.665282     5.608733   10.292788
# min     35013.000000     1.015000    5.000000
# 25%     62071.750000     5.193250   13.000000
# 50%     90428.000000     9.658500   22.000000
# 75%    118075.250000    14.965000   31.000000
# max    149908.000000    19.944000   41.000000

# %%
employ.info()
# attention, info permet d'afficher comment est construit le dataset,
# mais pas de se faire une idée de ce que contiennent les données
# alors que describe si :)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 764 entries, emp0 to emp763
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   firstname    764 non-null    object
#  1   lastname     764 non-null    object
#  2   genre        764 non-null    object
#  3   salaire      764 non-null    int64
#  4   bonus_pourc  764 non-null    float64
#  5   sen_man      764 non-null    bool
#  6   equipe       764 non-null    object
#  7   anciennete   764 non-null    int64
# dtypes: bool(1), float64(1), int64(2), object(4)
# memory usage: 64.7+ KB

# %%
### pour avoir des descriptions sur toutes les colonnes
employ.describe(include='all')
# Out:
#        firstname lastname   genre        salaire  bonus_pourc sen_man  \
# count        764      764     764     764.000000   764.000000     764
# unique       199      634       2            NaN          NaN       2
# top      Marilyn    Smith  Female            NaN          NaN   False
# freq          10       14     393            NaN          NaN     383
# mean         NaN      NaN     NaN   90433.196335    10.148041     NaN
# std          NaN      NaN     NaN   32864.665282     5.608733     NaN
# min          NaN      NaN     NaN   35013.000000     1.015000     NaN
# 25%          NaN      NaN     NaN   62071.750000     5.193250     NaN
# 50%          NaN      NaN     NaN   90428.000000     9.658500     NaN
# 75%          NaN      NaN     NaN  118075.250000    14.965000     NaN
# max          NaN      NaN     NaN  149908.000000    19.944000     NaN
#
#                       equipe  anciennete
# count                    764  764.000000
# unique                    10         NaN
# ...

# %%
### façon perso de travailler, je regarde
# d'une part les colonnes quanti
employ.describe()
# Out:
#              salaire  bonus_pourc  anciennete
# count     764.000000   764.000000  764.000000
# mean    90433.196335    10.148041   22.316754
# std     32864.665282     5.608733   10.292788
# min     35013.000000     1.015000    5.000000
# 25%     62071.750000     5.193250   13.000000
# 50%     90428.000000     9.658500   22.000000
# 75%    118075.250000    14.965000   31.000000
# max    149908.000000    19.944000   41.000000

# %%
# d'autre part les autres
employ.describe(exclude='number')
# Out:
#        firstname lastname   genre sen_man                equipe
# count        764      764     764     764                   764
# unique       199      634       2       2                    10
# top      Marilyn    Smith  Female   False  Business Development
# freq          10       14     393     383                    88

# %%
### exemple de dataviz d'exploration
plt.boxplot(employ["salaire"])
plt.title("Boxplot du salaire")
plt.show()
# ATTENTION aux boxplot que vous trouvez sur internet et à votre façon de les lire
# concernant le min et le max

# %% [markdown]
# # 4. Slicing

# %%
employ.head()
# Out:
#      firstname  lastname   genre  salaire  bonus_pourc  sen_man  \
# emp0   Douglas     Walsh    Male    97308        6.945     True
# emp1     Maria     Rhine  Female   130590       11.858    False
# emp2     Jerry     Stelk    Male   138705        9.340     True
# emp3     Larry  Sperdute    Male   101004        1.389     True
# emp4    Dennis    Wilson    Male   115163       10.125    False
#
#                equipe  anciennete
# emp0        Marketing          28
# emp1          Finance          28
# emp2          Finance          16
# emp3  Client Services          23
# emp4            Legal          34

# %% [markdown]
# * **L'équipe de l'employé 3**

# %%
employ.loc["emp3"] # ressort serie
# Out:
# firstname                Larry
# lastname              Sperdute
# genre                     Male
# salaire                 101004
# bonus_pourc              1.389
# sen_man                   True
# equipe         Client Services
# anciennete                  23
# Name: emp3, dtype: object

# %%
employ.loc["emp3", "equipe"]
# Out:
# 'Client Services'

# %%
employ.iloc[3, 6]
# Out:
# 'Client Services'

# %%
employ.iloc[3]["equipe"]
# Out:
# 'Client Services'

# %%
employ["equipe"].iloc[3]
# Out:
# 'Client Services'

# %% [markdown]
# * **Les colonnes firstname, lastname, genre**

# %% [markdown]
# ESSAIS N AYANT PAS ABOUTI :

# %%
employ.iloc[:, "firstname", "lastname", "genre"]
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-54-5d1d2089ba39> in <module>
# ----> 1 employ.iloc[:, "firstname", "lastname", "genre"]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1504     def _getitem_tuple(self, tup: tuple):
#    1505
# -> 1506         self._has_valid_tuple(tup)
#    1507         with suppress(IndexingError):
#    1508             return self._getitem_lowerdim(tup)
#
# ...

# %%
employ["firstname", "lastname", "genre"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('firstname', 'lastname', 'genre')
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
employ[["firstname"]]"lastname"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-59-e4e502a5fc9f> in <module>
# ----> 1 employ[["firstname"]["lastname"]]
#
# TypeError: list indices must be integers or slices, not str

# %%
employ["lastname" ]#["firstname"][ "genre" ]
# Out:
# emp0         Walsh
# emp1         Rhine
# emp2         Stelk
# emp3      Sperdute
# emp4        Wilson
#             ...
# emp759      Cooney
# emp760     Randall
# emp761    Martinez
# emp762        Able
# emp763      Earles
# Name: lastname, Length: 764, dtype: object

# %%
employ.iloc[:, ["firstname", "lastname", "genre"]]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-53-541bcb141226> in <module>
# ----> 1 employ.iloc[:, ["firstname", "lastname", "genre"]]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1504     def _getitem_tuple(self, tup: tuple):
#    1505
# -> 1506         self._has_valid_tuple(tup)
#    1507         with suppress(IndexingError):
#    1508             return self._getitem_lowerdim(tup)
#
# ...

# %% [markdown]
# VERSIONS QUI FONCTIONNENT :

# %%
employ[["equipe", "lastname", "firstname"]]
# Out:
#                       equipe  lastname firstname
# emp0               Marketing     Walsh   Douglas
# emp1                 Finance     Rhine     Maria
# emp2                 Finance     Stelk     Jerry
# emp3         Client Services  Sperdute     Larry
# emp4                   Legal    Wilson    Dennis
# ...                      ...       ...       ...
# emp759             Marketing    Cooney    George
# emp760               Finance   Randall   Phillip
# emp761               Product  Martinez   Russell
# emp762  Business Development      Able     Larry
# emp763                 Sales    Earles    Albert
#
# [764 rows x 3 columns]

# %%
employ.loc[:, "firstname":"genre"]
# Out:
#        firstname  lastname   genre
# emp0     Douglas     Walsh    Male
# emp1       Maria     Rhine  Female
# emp2       Jerry     Stelk    Male
# emp3       Larry  Sperdute    Male
# emp4      Dennis    Wilson    Male
# ...          ...       ...     ...
# emp759    George    Cooney    Male
# emp760   Phillip   Randall    Male
# emp761   Russell  Martinez    Male
# emp762     Larry      Able    Male
# emp763    Albert    Earles    Male
#
# [764 rows x 3 columns]

# %%
employ.loc[:, ["firstname", "lastname", "genre"]]
# Out:
#        firstname  lastname   genre
# emp0     Douglas     Walsh    Male
# emp1       Maria     Rhine  Female
# emp2       Jerry     Stelk    Male
# emp3       Larry  Sperdute    Male
# emp4      Dennis    Wilson    Male
# ...          ...       ...     ...
# emp759    George    Cooney    Male
# emp760   Phillip   Randall    Male
# emp761   Russell  Martinez    Male
# emp762     Larry      Able    Male
# emp763    Albert    Earles    Male
#
# [764 rows x 3 columns]

# %% [markdown]
# * **ressortir une seule colonne**

# %%
### en série
employ["equipe"]
# Out:
# emp0                 Marketing
# emp1                   Finance
# emp2                   Finance
# emp3           Client Services
# emp4                     Legal
#                   ...
# emp759               Marketing
# emp760                 Finance
# emp761                 Product
# emp762    Business Development
# emp763                   Sales
# Name: equipe, Length: 764, dtype: object

# %%
### en df
employ[["equipe"]]
# Out:
#                       equipe
# emp0               Marketing
# emp1                 Finance
# emp2                 Finance
# emp3         Client Services
# emp4                   Legal
# ...                      ...
# emp759             Marketing
# emp760               Finance
# emp761               Product
# emp762  Business Development
# emp763                 Sales
#
# [764 rows x 1 columns]

# %% [markdown]
# # 5. Questions auxquelles répondre

# %% [markdown]
# ## 5.1 Afficher la liste des salariés dans l'entreprise depuis + de 30 ans

# %%
### je définis une condition
cond = employ["anciennete"] >= 30
cond
# Out:
# emp0      False
# emp1      False
# emp2      False
# emp3      False
# emp4       True
#           ...
# emp759    False
# emp760     True
# emp761    False
# emp762    False
# emp763    False
# Name: anciennete, Length: 764, dtype: bool

# %%
### je filtre mon df sur la condition
employ.loc[cond]
# Out:
#        firstname  lastname   genre  salaire  bonus_pourc  sen_man  \
# emp4      Dennis    Wilson    Male   115163       10.125    False
# emp5        Ruby       Cox  Female    65476       10.012     True
# emp9     Brandon     Dunne    Male   112807       17.492     True
# emp14      Shawn  Craghead    Male   111737        6.414    False
# emp15      Diana  Gonzales  Female   132940       19.082    False
# ...          ...       ...     ...      ...          ...      ...
# emp749      Rose     White  Female    91411        8.639     True
# emp750      John        Yu    Male   146907       11.738    False
# emp752     Donna     Sweat  Female    82871       17.999    False
# emp755     Robin     White  Female   100765       10.982     True
# emp760   Phillip   Randall    Male    42392       19.675    False
#
#                  equipe  anciennete
# emp4              Legal          34
# emp5            Product          34
# emp9    Human Resources          41
# ...

# %%
# ou pour aller plus vite, j'écris tout d'un coup
# employ.loc[employ["anciennete"] >= 30]

# %%
### je récupère les prénoms satisfaisant la condition
employ.loc[cond, "firstname"]
# Out:
# emp4       Dennis
# emp5         Ruby
# emp9      Brandon
# emp14       Shawn
# emp15       Diana
#            ...
# emp749       Rose
# emp750       John
# emp752      Donna
# emp755      Robin
# emp760    Phillip
# Name: firstname, Length: 209, dtype: object

# %%
### je passe en type list
employ.loc[cond, "firstname"].tolist()
# Out:
# ['Dennis',
#  'Ruby',
#  'Brandon',
#  'Shawn',
#  'Diana',
#  'Terry',
#  'Linda',
#  'Stephanie',
#  'Marilyn',
#  'Cynthia',
#  'Roger',
#  'Todd',
#  'Bonnie',
#  'Margaret',
#  'Robin',
#  'Bonnie',
#  'Steven',
#  'Donna',
#  'Harry',
#  'Harold',
#  'John',
#  'Pamela',
#  'Marilyn',
#  'Michelle',
#  'Kenneth',
#  'Antonio',
#  'Shirley',
#  'Lois',
#  'Shirley',
#  'Adam',
#  'Rebecca',
#  'Terry',
#  'Sara',
#  'Sandra',
#  'Steven',
#  'Maria',
#  'Gary',
#  'Roger',
#  'Jonathan',
#  'Ruth',
#  'Evelyn',
#  'Julie',
#  'Irene',
#  'Kevin',
#  'Walter',
#  'Robert',
#  'Jimmy',
#  'Victor',
#  'Edward',
#  'Anne',
#  'Stephanie',
#  'Irene',
#  'Fred',
#  'Howard',
#  'Christine',
#  'Todd',
#  'Jessica',
#  'Tammy',
#  'Jesse',
#  'Emily',
#  'Alan',
#  'Jeremy',
#  'Mark',
#  'Marilyn',
#  'Benjamin',
#  'Harold',
#  'Judy',
#  'Jacqueline',
#  'Julie',
#  'Linda',
#  'Ruby',
#  'Samuel',
#  'Evelyn',
#  'Fred',
#  'Shirley',
#  'Michael',
#  'Lori',
#  'Philip',
# ...

# %% [markdown]
# ## 5.2 Ajouter une colonne nom complet

# %%
employ.head(3)
# Out:
#      firstname lastname   genre  salaire  bonus_pourc  sen_man     equipe  \
# emp0   Douglas    Walsh    Male    97308        6.945     True  Marketing
# emp1     Maria    Rhine  Female   130590       11.858    False    Finance
# emp2     Jerry    Stelk    Male   138705        9.340     True    Finance
#
#       anciennete
# emp0          28
# emp1          28
# emp2          16

# %%
employ["nom_complet"] = employ["firstname"] + " " + employ["lastname"]
employ.head()
# Out:
#      firstname  lastname   genre  salaire  bonus_pourc  sen_man  \
# emp0   Douglas     Walsh    Male    97308        6.945     True
# emp1     Maria     Rhine  Female   130590       11.858    False
# emp2     Jerry     Stelk    Male   138705        9.340     True
# emp3     Larry  Sperdute    Male   101004        1.389     True
# emp4    Dennis    Wilson    Male   115163       10.125    False
#
#                equipe  anciennete     nom_complet
# emp0        Marketing          28   Douglas Walsh
# emp1          Finance          28     Maria Rhine
# emp2          Finance          16     Jerry Stelk
# emp3  Client Services          23  Larry Sperdute
# emp4            Legal          34   Dennis Wilson

# %%
### pour supprimer la colonne que je viens de créer

### version 1
# employ.drop("nom_complet", axis=1, inplace=True)
# employ.head(3)

# %%
### version 2
# del employ["nom_complet"]

# %%
### version 3 : attention pas à toutes les sauces
serie_nomcomp = employ.pop("nom_complet")
serie_nomcomp
# Out:
# emp0         Douglas Walsh
# emp1           Maria Rhine
# emp2           Jerry Stelk
# emp3        Larry Sperdute
# emp4         Dennis Wilson
#                 ...
# emp759       George Cooney
# emp760     Phillip Randall
# emp761    Russell Martinez
# emp762          Larry Able
# emp763       Albert Earles
# Name: nom_complet, Length: 764, dtype: object

# %%
employ.head()
# Out:
#      firstname  lastname   genre  salaire  bonus_pourc  sen_man  \
# emp0   Douglas     Walsh    Male    97308        6.945     True
# emp1     Maria     Rhine  Female   130590       11.858    False
# emp2     Jerry     Stelk    Male   138705        9.340     True
# emp3     Larry  Sperdute    Male   101004        1.389     True
# emp4    Dennis    Wilson    Male   115163       10.125    False
#
#                equipe  anciennete
# emp0        Marketing          28
# emp1          Finance          28
# emp2          Finance          16
# emp3  Client Services          23
# emp4            Legal          34

# %% [markdown]
# Test sur integer

# %%
employ["salaire2"] = employ["salaire"]
employ.head()
# Out:
#      firstname  lastname   genre  salaire  bonus_pourc  sen_man  \
# emp0   Douglas     Walsh    Male    97308        6.945     True
# emp1     Maria     Rhine  Female   130590       11.858    False
# emp2     Jerry     Stelk    Male   138705        9.340     True
# emp3     Larry  Sperdute    Male   101004        1.389     True
# emp4    Dennis    Wilson    Male   115163       10.125    False
#
#                equipe  anciennete  salaire2
# emp0        Marketing          28     97308
# emp1          Finance          28    130590
# emp2          Finance          16    138705
# emp3  Client Services          23    101004
# emp4            Legal          34    115163

# %%
employ.pop("salaire2")
# Out:
# emp0       97308
# emp1      130590
# emp2      138705
# emp3      101004
# emp4      115163
#            ...
# emp759     98874
# emp760     42392
# emp761     96914
# emp762     60500
# emp763    129949
# Name: salaire2, Length: 764, dtype: int64

# %% [markdown]
# Retour à ma colonne nom complet :

# %%
employ.insert(0, "nom_complet", serie_nomcomp)

# %%
employ
# Out:
#              nom_complet firstname  lastname   genre  salaire  bonus_pourc  \
# emp0       Douglas Walsh   Douglas     Walsh    Male    97308        6.945
# emp1         Maria Rhine     Maria     Rhine  Female   130590       11.858
# emp2         Jerry Stelk     Jerry     Stelk    Male   138705        9.340
# emp3      Larry Sperdute     Larry  Sperdute    Male   101004        1.389
# emp4       Dennis Wilson    Dennis    Wilson    Male   115163       10.125
# ...                  ...       ...       ...     ...      ...          ...
# emp759     George Cooney    George    Cooney    Male    98874        4.479
# emp760   Phillip Randall   Phillip   Randall    Male    42392       19.675
# emp761  Russell Martinez   Russell  Martinez    Male    96914        1.421
# emp762        Larry Able     Larry      Able    Male    60500       11.985
# emp763     Albert Earles    Albert    Earles    Male   129949       10.169
#
#         sen_man                equipe  anciennete
# ...

# %% [markdown]
# ## 5.3 Afficher les employés Steven Powe et Marilyn Foster

# %%
employ
# Out:
#              nom_complet firstname  lastname   genre  salaire  bonus_pourc  \
# emp0       Douglas Walsh   Douglas     Walsh    Male    97308        6.945
# emp1         Maria Rhine     Maria     Rhine  Female   130590       11.858
# emp2         Jerry Stelk     Jerry     Stelk    Male   138705        9.340
# emp3      Larry Sperdute     Larry  Sperdute    Male   101004        1.389
# emp4       Dennis Wilson    Dennis    Wilson    Male   115163       10.125
# ...                  ...       ...       ...     ...      ...          ...
# emp759     George Cooney    George    Cooney    Male    98874        4.479
# emp760   Phillip Randall   Phillip   Randall    Male    42392       19.675
# emp761  Russell Martinez   Russell  Martinez    Male    96914        1.421
# emp762        Larry Able     Larry      Able    Male    60500       11.985
# emp763     Albert Earles    Albert    Earles    Male   129949       10.169
#
#         sen_man                equipe  anciennete
# ...

# %%
### version longue et moche si j'ai 10 noms à filtrer
cond = employ["nom_complet"] == "Steven Powe"
cond
# Out:
# emp0      False
# emp1      False
# emp2      False
# emp3      False
# emp4      False
#           ...
# emp759    False
# emp760    False
# emp761    False
# emp762    False
# emp763    False
# Name: nom_complet, Length: 764, dtype: bool

# %%
employ[cond]
# Out:
#         nom_complet firstname lastname genre  salaire  bonus_pourc  sen_man  \
# emp564  Steven Powe    Steven     Powe  Male   100949       13.813     True
#
#                  equipe  anciennete
# emp564  Human Resources          41

# %%
### version opti
cond = employ["nom_complet"].isin(["Steven Powe", "Marilyn Foster"])
cond
# Out:
# emp0      False
# emp1      False
# emp2      False
# emp3      False
# emp4      False
#           ...
# emp759    False
# emp760    False
# emp761    False
# emp762    False
# emp763    False
# Name: nom_complet, Length: 764, dtype: bool

# %%
employ[cond]
# Out:
#            nom_complet firstname lastname   genre  salaire  bonus_pourc  \
# emp31   Marilyn Foster   Marilyn   Foster  Female    73524        5.207
# emp564     Steven Powe    Steven     Powe    Male   100949       13.813
#
#         sen_man           equipe  anciennete
# emp31      True        Marketing          41
# emp564     True  Human Resources          41
